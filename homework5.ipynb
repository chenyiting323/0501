# %%
def cal(n1,o,n2):
    if o == "+":
        ans=n1+n2
        return ans
    
    if o == "-":
        ans=n1-n2
        return ans
    
    if o == "*":
        ans=n1*n2
        return ans
    
    if o == "/":
        ans=n1/n2
        return ans

n1=int(input("請輸入第一個數："))
o=input("請輸入運算符號(+-*/)：")
n2=int(input("請輸入第二個數："))    
    
print(cal(n1,o,n2))
# Out:
# 請輸入第一個數：1
# 請輸入運算符號(+-*/)：*
# 請輸入第二個數：5
# 5
